# %% [markdown]
# # AIF360 demo
# This notebook demonstrates a minimal fairness check using the Adult dataset and AIF360.

# %%
# Cell 2: imports and load data
import pandas as pd
from scripts.load_adult import load_adult
df = load_adult()
df.head()

# %%
# Cell 3: quick model train (for demo)
from scripts.train_model import train_and_save
train_and_save()
